# %% [markdown]
# # Rotten Tomatos Movies Reviews

# %% [markdown]
# Hi there,
#
# I’m the host of a movie reviews podcast and I’m currently making an episode about movie review aggregators.
#
# I found this data set from Rotten Tomatoes (inside the .ipynb file that I’ve attached). Could you dig into the data and share any interesting insights that you find? My audience loves fun facts about movies.
#
# Thank you!

# %% [markdown]
# # 0.1 Read the Data

# %%
import pandas as pd

# %%
rtomatosmovies = pd.read_csv('Rotten Tomatoes Movies-Copy1.csv')

# %%
# let's work with a subset of the data for this project
rtomatosmovies = rtomatosmovies[['movie_title', 'rating', 'genre', 'in_theaters_date','runtime_in_minutes',
                 'tomatometer_rating', 'tomatometer_count', 'audience_rating', 'audience_count']]
rtomatosmovies.head()
# Out:
#                                          movie_title rating  \
# 0  Percy Jackson & the Olympians: The Lightning T...     PG
# 1                                        Please Give      R
# 2                                                 10      R
# 3                    12 Angry Men (Twelve Angry Men)     NR
# 4                       20,000 Leagues Under The Sea      G
#
#                                                genre in_theaters_date  \
# 0  Action & Adventure, Comedy, Drama, Science Fic...       2010-02-12
# 1                                             Comedy       2010-04-30
# 2                                    Comedy, Romance       1979-10-05
# 3                                    Classics, Drama       1957-04-13
# 4           Action & Adventure, Drama, Kids & Family       1954-01-01
#
#    runtime_in_minutes  tomatometer_rating  tomatometer_count  audience_rating  \
# 0                83.0                  49                144             53.0
# 1                90.0                  86                140             64.0
# 2               118.0                  68                 22             53.0
# 3                95.0                 100                 51             97.0
# 4               127.0                  89                 27             74.0
#
#    audience_count
# 0        254287.0
# 1         11567.0
# 2         14670.0
# 3        105000.0
# 4         68860.0

# %%
# number the rows and columns 
rtomatosmovies.shape
# Out:
# (16638, 9)

# %%
rtomatosmovies.head(1)
# Out:
#                                          movie_title rating  \
# 0  Percy Jackson & the Olympians: The Lightning T...     PG
#
#                                                genre in_theaters_date  \
# 0  Action & Adventure, Comedy, Drama, Science Fic...       2010-02-12
#
#    runtime_in_minutes  tomatometer_rating  tomatometer_count  audience_rating  \
# 0                83.0                  49                144             53.0
#
#    audience_count
# 0        254287.0

# %% [markdown]
# ## 1. Explore the Data

# %%
# Check Data tybe 
rtomatosmovies.dtypes
# Out:
# movie_title                   object
# rating                        object
# genre                         object
# in_theaters_date      datetime64[ns]
# runtime_in_minutes           float64
# tomatometer_rating             int64
# tomatometer_count              int64
# audience_rating              float64
# audience_count               float64
# dtype: object

# %%
# convert the in_theatres_date to a datetime field
rtomatosmovies['in_theaters_date'] = pd.to_datetime(rtomatosmovies.in_theaters_date)
rtomatosmovies.head(3)
# Out:
# /var/folders/4d/t5r7tnq552qb8_j64ldwt_h00000gn/T/ipykernel_20187/2130520270.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rtomatosmovies['in_theaters_date'] = pd.to_datetime(rtomatosmovies.in_theaters_date)
#                                          movie_title rating  \
# 0  Percy Jackson & the Olympians: The Lightning T...     PG
# 1                                        Please Give      R
# 2                                                 10      R
#
#                                                genre in_theaters_date  \
# 0  Action & Adventure, Comedy, Drama, Science Fic...       2010-02-12
# 1                                             Comedy       2010-04-30
# 2                                    Comedy, Romance       1979-10-05
#
#    runtime_in_minutes  tomatometer_rating  tomatometer_count  audience_rating  \
# 0                83.0                  49                144             53.0
# 1                90.0                  86                140             64.0
# 2               118.0                  68                 22             53.0
#
#    audience_count
# 0        254287.0
# 1         11567.0
# 2         14670.0

# %%
# filter on only movies from the 2010's and newer
rtomatosmovies = rtomatosmovies[rtomatosmovies.in_theaters_date.dt.year >= 2010]
rtomatosmovies.head(3)
# Out:
#                                           movie_title rating  \
# 0   Percy Jackson & the Olympians: The Lightning T...     PG
# 1                                         Please Give      R
# 97                            Fireflies in the Garden      R
#
#                                                 genre in_theaters_date  \
# 0   Action & Adventure, Comedy, Drama, Science Fic...       2010-02-12
# 1                                              Comedy       2010-04-30
# 97                                              Drama       2011-10-14
#
#     runtime_in_minutes  tomatometer_rating  tomatometer_count  \
# 0                 83.0                  49                144
# 1                 90.0                  86                140
# 97                98.0                  22                 54
#
#     audience_rating  audience_count
# 0              53.0        254287.0
# 1              64.0         11567.0
# 97             45.0         45150.0

# %%
rtomatosmovies.in_theaters_date.dt.year
# Out:
# 0        2010.0
# 1        2010.0
# 2        1979.0
# 3        1957.0
# 4        1954.0
#           ...
# 16633    1981.0
# 16634    2016.0
# 16635    1964.0
# 16636    1964.0
# 16637    1979.0
# Name: in_theaters_date, Length: 16638, dtype: float64

# %%
# find the number of movies
rtomatosmovies.shape
# Out:
# (6053, 9)

# %% [markdown]
# Find the highest rated movies according to both critics (*tomatometer_rating*) and the general audience (*audience_rating*).

# %%
# highest rated movies by critics
rtomatosmovies.sort_values('tomatometer_rating', ascending=False).head()
# Out:
#                                   movie_title rating  \
# 3093  Batman: The Dark Knight Returns, Part 1  PG-13
# 8500                             King Georges     NR
# 8495                         King Charles III     NR
# 8477       Killing for Love (Das Versprechen)     NR
# 8461             Kill Zone 2 (Saat po long 2)     NR
#
#                                                   genre in_theaters_date  \
# 3093                      Action & Adventure, Animation       2012-01-01
# 8500                                        Documentary       2016-02-26
# 8495                                              Drama       2017-05-14
# 8477             Art House & International, Documentary       2017-12-15
# 8461  Action & Adventure, Art House & International,...       2016-05-13
#
#       runtime_in_minutes  tomatometer_rating  tomatometer_count  \
# 3093               134.0                 100                  5
# 8500                78.0                 100                  9
# 8495                88.0                 100                  9
# 8477               124.0                 100                  9
# 8461               120.0                 100                 22
#
#       audience_rating  audience_count
# 3093             93.0          8482.0
# 8500             54.0           240.0
# 8495             48.0            65.0
# 8477             82.0           201.0
# 8461             63.0           544.0

# %%
# highest rated movies by the audience
rtomatosmovies.sort_values('audience_rating', ascending=False).head()
# Out:
#                    movie_title rating                                 genre  \
# 14566        The Miners' Hymns     NR  Documentary, Drama, Special Interest
# 9051           Little Monsters      R                        Comedy, Horror
# 7137                     Haunt      R            Horror, Mystery & Suspense
# 16438       Wonders of the Sea     NR                           Documentary
# 14580  The Most Dangerous Year     NR                           Documentary
#
#       in_theaters_date  runtime_in_minutes  tomatometer_rating  \
# 14566       2012-02-08                52.0                 100
# 9051        2019-10-08                94.0                  83
# 7137        2019-09-13                92.0                  68
# 16438       2019-01-17                82.0                  76
# 14580       2019-04-12                90.0                  91
#
#        tomatometer_count  audience_rating  audience_count
# 14566                 10            100.0           148.0
# 9051                  94            100.0             9.0
# 7137                  38            100.0             7.0
# 16438                 17            100.0            13.0
# 14580                 11            100.0            40.0

# %% [markdown]
# These top movies seem to have very few critics and audience members writing the reviews. We want to look at only the most popular movies. Filter the movies data set to only include movies that have 100k+ audience ratings. How many movies are in this data set?

# %%
# there are about 300 movies for us to work with
movies_popular = rtomatosmovies[rtomatosmovies.audience_count > 100000]
movies_popular.shape
# Out:
# (316, 9)

# %% [markdown]
# Find the highest rated **popular** movies according to both critics (*tomatometer_rating*) and the general audience (*audience_rating*).

# %%
# highest rated popular movies by critics
movies_popular.sort_values('tomatometer_rating', ascending=False).head()
# Out:
#                     movie_title rating  \
# 7558   How to Train Your Dragon     PG
# 15416               Toy Story 3      G
# 7925                 Inside Out     PG
# 16634                  Zootopia     PG
# 9355         Mad Max: Fury Road      R
#
#                                                    genre in_theaters_date  \
# 7558   Animation, Kids & Family, Science Fiction & Fa...       2010-03-26
# 15416                   Animation, Comedy, Kids & Family       2010-06-18
# 7925                            Animation, Kids & Family       2015-06-19
# 16634              Action & Adventure, Animation, Comedy       2016-03-04
# 9355       Action & Adventure, Science Fiction & Fantasy       2015-05-15
#
#        runtime_in_minutes  tomatometer_rating  tomatometer_count  \
# 7558                 98.0                  99                208
# 15416               103.0                  98                305
# 7925                 94.0                  98                357
# 16634               108.0                  97                279
# 9355                120.0                  97                410
#
#        audience_rating  audience_count
# 7558              91.0        312342.0
# 15416             89.0        606931.0
# 7925              89.0        136125.0
# 16634             92.0        100946.0
# 9355              85.0        127428.0

# %%
# highest rated popular movies by the audience
movies_popular.sort_values('audience_rating', ascending=False).head()
# Out:
#                                movie_title rating  \
# 16634                             Zootopia     PG
# 6950               Guardians of the Galaxy  PG-13
# 4077   Captain America: The Winter Soldier  PG-13
# 14397                    The King's Speech  PG-13
# 14549                          The Martian  PG-13
#
#                                                genre in_theaters_date  \
# 16634          Action & Adventure, Animation, Comedy       2016-03-04
# 6950   Action & Adventure, Science Fiction & Fantasy       2014-08-01
# 4077   Action & Adventure, Science Fiction & Fantasy       2014-04-04
# 14397                                          Drama       2010-11-26
# 14549                      Science Fiction & Fantasy       2015-10-02
#
#        runtime_in_minutes  tomatometer_rating  tomatometer_count  \
# 16634               108.0                  97                279
# 6950                121.0                  91                316
# 4077                136.0                  90                292
# 14397               118.0                  95                292
# 14549               164.0                  91                361
#
#        audience_rating  audience_count
# 16634             92.0        100946.0
# 6950              92.0        254717.0
# 4077              92.0        281524.0
# 14397             92.0        144306.0
# 14549             91.0        131093.0

# %% [markdown]
# A lot of these popular movies seem to have a PG or PG-13 rating. How many movies fall under each type of rating?
#
# *Use this popular movies data set going forward in this notebook.*

# %%
# number of movies that fall under each type of rating
movies_popular.rating.value_counts()
# Out:
# rating
# PG-13    160
# R        100
# PG        51
# G          5
# Name: count, dtype: int64

# %% [markdown]
# What is the average audience rating for each movie rating type? Which rating type is most highly rated?

# %%
# PG-13 movies are most highly rated
movies_popular.groupby('rating')['audience_rating'].mean()
# Out:
# rating
# G        66.200000
# PG       66.823529
# PG-13    67.293750
# R        63.010000
# Name: audience_rating, dtype: float64
